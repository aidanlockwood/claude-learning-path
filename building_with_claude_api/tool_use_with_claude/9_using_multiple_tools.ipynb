# %% [markdown]
# # Using Multiple Tools

# %%
from utils.util_funcs import *

client, model = api_client_setup()

# %%
messages = []

add_user_message(
    messages, 
    "Set a reminder for my doctor's appointment. It's 177 days after Jan 1st, 2050"
)

run_conversation(messages)
# Out:
# I'll help you set a reminder for your doctor's appointment. First, let me calculate the date that is 177 days after January 1st, 2050.
# Perfect! The date is Monday, June 27, 2050. Now I'll set a reminder for your doctor's appointment at that date. I'll schedule it for noon on that day:
# ----
# Setting the following reminder for 2050-06-27T12:00:00:
# Doctor's appointment
# ----
# Done! I've set a reminder for your doctor's appointment on **Monday, June 27, 2050 at 12:00 PM**. You'll receive a notification at that time.
