# %% [markdown]
# # Project Overview

# %% [markdown]
# We are going to be building an application that allows Claude to set reminders for future dates in time.
#
# **The Problem with Default Claude**
# 1. It has limited time awareness
# - Doesn't know about the exact time of day, but might know the current date
# 2. Date calculation issues
# - Doesn't know how to add/subtract times very well
# 3. No Reminder capability
# - Doesn't know how to set a reminder
#
# Therefore, to solve this problem, we need tools
