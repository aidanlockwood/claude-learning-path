# %% [markdown]
# # The Text Edit Tool

# %% [markdown]
# Built directly into Claude.
# - Allows create, read and edit to both directories and files
# - Only the JSON schema into Claude, developers need to provide the full implementation (the function) of it
#     - Note that when making custom tools, we provided both the **function implementation** AND the **JSON Schema**
#         - There's less work to do for the text edit tool

# %%
from utils.util_funcs import *
from utils.text_editor_tool import TextEditorTool
from IPython.display import Markdown

client, model = api_client_setup()
print(f'Using model: "{model}" from client: {client}')
# Out:
# Using model: "claude-haiku-4-5" from client: <anthropic.Anthropic object at 0x1103ca520>

# %%
messages = []
add_user_message(
    messages, 
    """ 
    Open the ./main.py file and write out a function to calculate pi to the 5th digit.

    Then create a ./test.py file to test you implementation
    """
)

run_conversation(messages)
# Out:
# I'll help you create a function to calculate pi to the 5th digit in main.py and then create a test file. Let me start by examining the current directory structure.
# Good, the main.py file already exists. Let me check its current content:
# Now I'll add a function to calculate pi to the 5th digit. I'll use the Bailey–Borwein–Plouffe formula or Machin's formula for a simple and accurate calculation:
# Now let me create the test.py file to test the implementation:
# Perfect! I've successfully created both files. Let me verify the contents:
#
# Perfect! I've successfully completed your request. Here's what I've created:
#
# ## Summary
#
# ### 1. **main.py** - Added `calculate_pi_to_5_digits()` function
#    - Uses **Machin's formula** for accurate pi calculation: `pi/4 = 4*arctan(1/5) - arctan(1/239)`
#    - Implements the arctan function using Taylor series expansion
#    - Uses Python's `Decimal` module for high precision arithmetic (50 decimal places)
# ...

# %%
messages
# Out:
# [{'role': 'user',
#   'content': [{'type': 'text',
#     'text': ' \n    Open the ./main.py file and write out a function to calculate pi to the 5th digit.\n\n    Then create a ./test.py file to test you implementation\n    '}]},
#  {'role': 'assistant',
#   'content': [TextBlock(citations=None, text="I'll help you create a function to calculate pi to the 5th digit in main.py and then create a test file. Let me start by examining the current directory structure.", type='text'),
#    ToolUseBlock(id='toolu_01W5shfP89RioKitGPrXdrcd', caller=DirectCaller(type='direct'), input={'command': 'view', 'path': '.'}, name='str_replace_based_edit_tool', type='tool_use')]},
#  {'role': 'user',
#   'content': [{'type': 'tool_result',
#     'tool_use_id': 'toolu_01W5shfP89RioKitGPrXdrcd',
# ...
