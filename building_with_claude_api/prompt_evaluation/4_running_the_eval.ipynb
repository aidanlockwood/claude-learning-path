# %% [markdown]
# # Running the eval

# %%
from utils.util_funcs import *
import json

client, model = api_client_setup()

# %% [markdown]
# **The prompts used to achieve the evaluation pipeline in this instance are inside the util_funcs module, `run_prompt`, `run_test_case`, `run_eval`**

# %% [markdown]
# ### Loading the dataset into the notebook

# %%
with open('dataset.json', 'r') as f: 
    dataset = json.load(f)

results = run_eval(dataset)
print(results)
# Out:
# 6.5
# [{'output': '# AWS IAM Role ARN Validator\n\n```python\nimport re\n\ndef validate_iam_role_arn(arn: str) -> bool:\n    """\n    Validates an AWS IAM role ARN and returns True if it matches the correct format.\n    \n    AWS IAM Role ARN Format:\n    arn:aws:iam::<account-id>:role/<role-name>\n    \n    Where:\n    - account-id: 12-digit number\n    - role-name: 1-128 characters, alphanumeric and +=,.@_/-\n    \n    Args:\n        arn (str): The ARN string to validate\n        \n    Returns:\n        bool: True if valid IAM role ARN, False otherwise\n    """\n    \n    # Define the regex pattern for AWS IAM role ARN\n    # Pattern breakdown:\n    # ^arn:aws:iam:: - literal prefix\n    # \\d{12} - exactly 12 digits for account ID\n    # :role/ - literal separator\n    # [a-zA-Z0-9\\-_/+=,.@]+ - valid role name characters\n    # $ - end of string\n    \n    pattern = r\'^arn:aws:iam::\\d{12}:role/[a-zA-Z0-9\\-_/+=,.@]+$\'\n    \n    # Check if the ARN matches the pattern\n    return bool(re.match(pattern, arn)) if isinstance(arn, str) else False\n\n\n# Test cases\nif __name__ == "__main__":\n    # Valid ARNs\n    valid_arns = [\n        "arn:aws:iam::123456789012:role/MyRole",\n        "arn:aws:iam::999999999999:role/service-role/MyServiceRole",\n        "arn:aws:iam::000000000000:role/my-role-name",\n        "arn:aws:iam::123456789012:role/role_with_underscore",\n        "arn:aws:iam::123456789012:role/role.with.dots",\n        "arn:aws:iam::123456789012:role/role+with+plus",\n        "arn:aws:iam::123456789012:role/role=with=equals",\n        "arn:aws:iam::123456789012:role/role,with,commas",\n    ]\n    \n    # Invalid ARNs\n    invalid_arns = [\n        "arn:aws:iam::12345678901:role/MyRole",  # 11 digits (too short)\n        "arn:aws:iam::1234567890123:role/MyRole",  # 13 digits (too long)\n        "arn:aws:iam::123456789012:user/MyUser",  # \'user\' instead of \'role\'\n        "arn:aws:iam::123456789012:MyRole",  # Missing \'role/\' prefix\n        "arn:aws:s3:::my-bucket/key",  # S3 ARN, not IAM role\n        "arn:aws:iam::123456789012:role/",  # Missing role name\n        "arn:aws:iam:region:123456789012:role/MyRole",  # Region specified (should be empty)\n        "invalid-arn-string",  # Not an ARN at all\n        "",  # Empty string\n        None,  # Not a string\n        123,  # Integer\n    ]\n    \n    print("Testing Valid ARNs:")\n    print("-" * 60)\n    for arn in valid_arns:\n        result = validate_iam_role_arn(arn)\n        status = "✓ PASS" if result else "✗ FAIL"\n        print(f"{status}: {arn}")\n    \n    print("\\nTesting Invalid ARNs:")\n    print("-" * 60)\n    for arn in invalid_arns:\n        result = validate_iam_role_arn(arn)\n        status = "✓ PASS" if not result else "', 'test_case': {'task': 'Write a Python function that validates an AWS IAM role ARN and returns True if it matches the correct format, False otherwise'}, 'score': 7, 'reasoning': 'The solution demonstrates solid understanding of AWS IAM ARN format and implements a mostly correct regex pattern. The test coverage is thorough and the type checking is appropriate. However, the code is incomplete (truncated output), and there are minor issues with the regex allowing path-like characters that may exceed AWS specifications. The role name length constraint mentioned in docstring is not enforced in the regex pattern.'}, {'output': '# AWS S3 Bucket Policy - Read-Only Access with Prefix\n\n```json\n{\n  "Version": "2012-10-17",\n  "Statement": [\n    {\n      "Sid": "AllowReadOnlyAccessWithPrefix",\n      "Effect": "Allow",\n      "Principal": {\n        "AWS": "arn:aws:iam::ACCOUNT-ID:root"\n      },\n      "Action": [\n        "s3:GetObject",\n        "s3:GetObjectVersion"\n      ],\n      "Resource": "arn:aws:s3:::my-bucket-name/specific-prefix/*",\n      "Condition": {\n        "StringLike": {\n          "aws:userid": "*"\n        }\n      }\n    },\n    {\n      "Sid": "AllowListBucketWithPrefix",\n      "Effect": "Allow",\n      "Pr ...

# %% [markdown]
# ### Running the eval pipeline
