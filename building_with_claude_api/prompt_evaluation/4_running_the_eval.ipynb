# %% [markdown]
# # Running the eval

# %%
from utils.util_funcs import *
import json

client, model = api_client_setup()

# %% [markdown]
# **The prompts used to achieve the evaluation pipeline in this instance are inside the util_funcs module, `run_prompt`, `run_test_case`, `run_eval`**

# %% [markdown]
# ### Loading the dataset into the notebook

# %%
with open('dataset.json', 'r') as f: 
    dataset = json.load(f)

results = run_eval(dataset)
print(results)
# Out:
# 7.583333333333333
# ...

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "import re\n\ndef parse_s3_uri(uri):\n    # Match s3://bucket-name/object/key or s3://bucket-name/object-key\n    pattern = r'^s3://([a-z0-9.-]+)/(.+)$'\n    match = re.match(pattern, uri)\n    \n    if match:\n        bucket_name = match.group(1)\n        object_key = match.group(2)\n        return {'bucket': bucket_name, 'key': object_key}\n    else:\n        raise ValueError('Invalid S3 URI format')\n\n# Example usage\nuri = 's3://my-bucket/path/to/object.txt'\nresult = parse_s3_uri(uri)\nprint(result)",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket name and object key from an S3 URI",
#       "format": "regex",
#       "solution_criteria": "Must include a regex pattern that captures the bucket name and object key from URIs in the format s3://bucket-name/path/to/object"
#     },
#     "score": 8.5,
# ...
