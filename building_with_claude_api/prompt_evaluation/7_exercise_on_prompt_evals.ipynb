# %% [markdown]
# # Exercise on Prompt Evals

# %% [markdown]
# The quality of the model grader can be achieved with two steps.
# 1. Updating the dataset generation prompt to include some selection criteria for each test case
# 2. Updating the grade by model prompt to include the selection criteria
