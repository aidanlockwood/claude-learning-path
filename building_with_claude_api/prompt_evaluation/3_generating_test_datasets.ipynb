# %% [markdown]
# # Generating Test Datasets

# %% [markdown]
# Setting up the Goal:
#
# Assisting the user in AWS queries, they might be asking for
# - Python code
# - JSON config files
# - Regex

# %%
from utils.util_funcs import *

client, model = api_client_setup()

# %%
# Confirming the model being used
model
# Out:
# 'claude-haiku-4-5'

# %% [markdown]
# Generating the evaluation dataset and saving

# %%
dataset = generate_dataset()

with open('dataset.json', 'w') as f: 
    json.dump(dataset, f, indent = 2)
