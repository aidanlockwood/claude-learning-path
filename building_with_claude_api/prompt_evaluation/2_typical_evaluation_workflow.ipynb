# %% [markdown]
# # Typical Evaluation Workflow

# %% [markdown]
# ## Drafting a Prompt
#
# The goal:
# - Writing a prompt to assist users in writing Python code, JSON Config or Regex focused on AWS-specific use cases
#
# - Input
#     - User requests code for task
# - Output
#     - Python, JSON, Regex, with no explanations

# %%
from utils.util_funcs import *

client, model = api_client_setup()

# %%
# Confirming the model being used
model
# Out:
# 'claude-haiku-4-5'

# %%
dataset = generate_dataset()

with open('dataset.json', 'w') as f: 
    json.dump(dataset, f, indent = 2)
# Out:
# [{'task': "Create a Python function that parses an AWS EC2 instance ID from a string like 'Instance: i-1234567890abcdef0' and returns just the ID"},
#  {'task': 'Write a regular expression that matches valid AWS S3 bucket names (lowercase letters, numbers, hyphens, 3-63 characters, cannot start/end with hyphen)'},
#  {'task': 'Generate a JSON object representing an AWS Lambda function configuration with function name, runtime, role ARN, and handler properties'}]
