# %% [markdown]
# # Model Based Grading
#
# One method to use for prompt evaluation. This method is good for:
# - Response quality
# - Quality of instruction after
# - Completeness
# - Helpfulness
# - Safety

# %%
from utils.util_funcs import *

client, model = api_client_setup()

# %% [markdown]
# ## Evaluation Criteria
# For the AWS example, the criteria is:
#
# Format **[CODE GRADER TASK]**
# - Should only return Python, JSON, or regex without an explanation
#
# Valid Syntax **[CODE GRADER]**
# - Produced Python, JSON and Regex should have valid syntax
#
# Task Following **[MODEL GRADER]**
# - Should directly and clearly address user task
# - Generated code should be accurate
