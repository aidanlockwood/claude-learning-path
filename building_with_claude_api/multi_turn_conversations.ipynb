# %% [markdown]
# # Multi-Turn Conversations

# %% [markdown]
# **Important**
# Anthropic API and Claude do not store message
#
# To maintain a conversation in the app, you need to:
# - manually maintain the full list of messages in your code
# - align each message with their follow up requests

# %%
from utils.util_funcs import api_client_setup

# %% [markdown]
# ### Helper functions to maintain a conversation history

# %%
client, model = api_client_setup()

def add_user_message(messages, text):
    user_message = { 
        'role': 'user', 
        'content': text
    }
    messages.append(user_message)

def add_assistant_message(messages, text):
    assistant_message = { 
        'role': 'assistant', 
        'content': text
    }
    messages.append(assistant_message)

def chat(messages): 
    message = client.messages.create(
        model = model,
        max_tokens = 1000,
        messages = messages
    )
    return message.content[0].text

# %% [markdown]
# ## Developing the Chat History

# %% [markdown]
# Creating a starting list of messages

# %%
messages = []

# %% [markdown]
# Initialise with the first user message

# %%
add_user_message(messages, "Define quantum computing in one sentence")
messages
# Out:
# [{'role': 'user', 'content': 'Define quantum computing in one sentence'}]

# %% [markdown]
# Pass the list of messages into the `chat` function

# %%
answer = chat(messages)

# %% [markdown]
# Apply the response from Claude as an `assistant message`

# %%
add_assistant_message(messages, answer)
messages
# Out:
# [{'role': 'user', 'content': 'Define quantum computing in one sentence'},
#  {'role': 'assistant',
#   'content': 'Quantum computing is a type of computation that harnesses the principles of quantum mechanics—such as superposition and entanglement—to process information in ways that can solve certain complex problems exponentially faster than classical computers.'}]

# %% [markdown]
# The output from the above cell should be an alternating list of `'role': 'user'` and `'role': 'assistant'` <br><br>
# Now adding a follow up question to show persistence of the chat history

# %%
add_user_message(messages, "Write another sentence")

answer = chat(messages)
answer
# Out:
# 'Unlike classical bits, which represent either a 0 or a 1, quantum computers use qubits that can exist in multiple states simultaneously, enabling them to explore many possible solutions in parallel.'

# %% [markdown]
# Displaying the conversation array

# %%
for message in messages:
    print(f"{message['role']}: {message['content']}")
# Out:
# user: Define quantum computing in one sentence
# assistant: Quantum computing is a type of computation that harnesses the principles of quantum mechanics—such as superposition and entanglement—to process information in ways that can solve certain complex problems exponentially faster than classical computers.
# user: Write another sentence

# %% [markdown]
# The result should include an assistant response that is still relevant to quantum computing (in this case)
