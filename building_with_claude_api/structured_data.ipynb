# %% [markdown]
# # Structured Data

# %% [markdown]
# Sometimes, users might want structured data to be able to complete their task. This means that the output of Claude needs to be usable and easy for a non-technical user to use.
#
# In this use-case, we want only the content and **nothing else**

# %%
from utils.util_funcs import *

client, model = api_client_setup(model = 'claude-sonnet-4-5')
print(f'You are using the model {model}')
# Out:
# You are using the model claude-sonnet-4-5

# %% [markdown]
# **Note: the `stop_sequences` argument in the CPN Learning Content is outdated in favour of defining the configuration through the output_config dictionary**
#
# Defining this schema here, before applying it to the chat

# %%
output_config = {
    "format": {
        "type": "json_schema",
        "schema": {
            "type": "object",
            "properties": {
                "source": {
                    "type": "array",
                    "items": {
                        "type": "string"
                    }
                },
                "detail-type": {
                    "type": "array",
                    "items": {
                        "type": "string"
                    }
                },
                "detail": {
                    "type": "object",
                    "properties": {
                        "state": {
                            "type": "array",
                            "items": {
                                "type": "string"
                            }
                        }
                    },
                    "required": ["state"],
                    "additionalProperties": False
                }
            },
            "required": ["source", "detail-type", "detail"],
            "additionalProperties": False
        }
    }
}

# %%
messages = []

add_user_message(messages, 'Generate a very short event bridge rule as json. Return only raw JSON and nothing else.')
answer = chat(messages, output_config=output_config)

answer

# %%
import json 
json.loads(answer)
# Out:
# {'source': ['aws.ec2'],
#  'detail-type': ['EC2 Instance State-change Notification'],
#  'detail': {'state': ['running']}}
