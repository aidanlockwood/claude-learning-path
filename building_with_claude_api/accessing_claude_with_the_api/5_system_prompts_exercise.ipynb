# %% [markdown]
# # System Prompts Exercise

# %% [markdown]
# Creating a Python function that checks a string for duplicate characters

# %%
from utils.util_funcs import *

client, model = api_client_setup()

# %%
messages = []

add_user_message(messages, "Write a python function that checks a string for duplicate characters.")

answer = chat(messages, system = "You are a Python programming expert, who can provide concise code. Provide only the code in the response, no explanations or comments.")

# %%
answer
# Out:
# '```python\ndef has_duplicates(s):\n    return len(s) != len(set(s))\n```'

# %% [markdown]
# Testing Claude's output

# %%
def has_duplicate_characters(s):
    return len(s) != len(set(s))

print(has_duplicate_characters("hello"))  # True
print(has_duplicate_characters("world"))  # False
# Out:
# True
# False
