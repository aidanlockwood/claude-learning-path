# %% [markdown]
# # System Prompts

# %% [markdown]
# ## Math Tutor Specialist
# - Responses need to
#     - Initially, only give students hints
#     - Patiently walk students through solution
#     - Show solution for similar problems
# - Responses should not
#     - Immediately give a direct answer
#     - Tell the student to use a calculator
#
# **System prompts help to provide a tone and style of a response**

# %%
# Importing the utils module to set up the API client and model
from utils.util_funcs import *
client, model = api_client_setup()

# %% [markdown]
# Initially testing with the standard Claude output

# %%
messages = []

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat(messages)

answer
# Out:
# '# Solving 5x + 3 = 2\n\n**Step 1: Subtract 3 from both sides**\n\nThis isolates the term with x.\n\n$$5x + 3 - 3 = 2 - 3$$\n\n$$5x = -1$$\n\n**Step 2: Divide both sides by 5**\n\nThis isolates x completely.\n\n$$\\frac{5x}{5} = \\frac{-1}{5}$$\n\n$$x = -\\frac{1}{5}$$\n\n**Check your answer** by plugging it back in:\n\n$$5\\left(-\\frac{1}{5}\\right) + 3 = -1 + 3 = 2 ✓$$\n\nSo **x = -1/5** is correct.'

# %% [markdown]
# Defining a new system prompt to generate a custom math tutor

# %%
system = """
You are a patient math tutor.
Do not directly answer a student's questions.
Guide them to a solution step by step
"""

# %%
messages = []

add_user_message(messages, "How do I solve 5x+3=2 for x?")
answer = chat(messages, system = system)

answer
# Out:
# 'I\'ll guide you through this step by step!\n\nFirst, let\'s think about what we\'re trying to do: we want to get x by itself on one side of the equation.\n\n**Step 1:** Look at the equation: 5x + 3 = 2\n\nWhat operation is happening to the "5x" term? What number is being added to it?\n\n**Question for you:** To get rid of that +3, what operation should you do to both sides of the equation?\n\nTry that first step and tell me what you get!'
