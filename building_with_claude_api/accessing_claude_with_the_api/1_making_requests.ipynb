# %% [markdown]
# ## Making Requests with Claude API

# %% [markdown]
# ## Installing the Anthropic Python SDK and 'python-dotenv'

# %%
#%pip install anthropic python-dotenv

# %% [markdown]
# ## Loading Environment Variables

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Creating the API Client

# %%
from utils.util_funcs import api_client_setup

client, model = api_client_setup()

# %% [markdown]
# To make requests to Claude, the `create()` function is used. Taking in the parameters:
# - `model`
#     - the name of the Claude model being used
# - `max_tokens`
#     - The maximum number of tokens for the response to output
#     - If Claude responds with more than this argument. The return will only include the length equal to the `max_tokens` argument
# - `messages`
#     - the input being provided to the model
#
# **Messages Argument**:
# Two types of messages exist for input into Claude
# - User Message:
#     - Text written by some person (developer/user)
# - Assistant Message:
#     - Model-Generated text

# %%
# Making a request to the Claude API
message = client.messages.create(
    model = model,
    max_tokens = 1000,
    messages = [{ 
        'role': 'user',
        'content': 'What is quantum computing? Answer in one sentence'
    }]
)

# %% [markdown]
# Displaying the full text body of the request

# %%
message.content
# Out:
# [TextBlock(citations=None, text='Quantum computing is a type of computation that uses the principles of quantum mechanics—such as superposition and entanglement—to process information in ways that can solve certain complex problems much faster than traditional computers.', type='text')]

# %% [markdown]
# Accessing the text component of the response

# %%
message.content[0].text
# Out:
# 'Quantum computing is a type of computation that uses the principles of quantum mechanics—such as superposition and entanglement—to process information in ways that can solve certain complex problems much faster than traditional computers.'
