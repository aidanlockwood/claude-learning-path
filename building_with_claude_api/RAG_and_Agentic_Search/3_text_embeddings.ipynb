# %% [markdown]
# # Text Embeddings

# %% [markdown]
# ### Using Semantic Search to Find Relevant Chunks
# Text Embeddings help to achieve this.
#
# **Text Embeddings** are a numerical representation of the meaning of a given word

# %%
# %pip install voyageai
# Out:
# ...
#   Using cached numpy-2.5.1-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached pillow-12.3.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (9.1 kB)
# ...
#   Using cached requests-2.34.2-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached pyyaml-6.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.4 kB)
# ...
#   Using cached jsonpointer-3.1.1-py3-none-any.whl.metadata (2.4 kB)
# ...
#   Using cached charset_normalizer-3.4.9-cp314-cp314-macosx_10_15_universal2.whl.metadata (41 kB)
# ...
#   Using cached urllib3-2.7.0-py3-none-any.whl.metadata (6.9 kB)
# ...
#   Using cached attrs-26.1.0-py3-none-any.whl.metadata (8.8 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 558.3/558.3 kB 23.3 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 661.3/661.3 kB 29.5 MB/s  0:00:00
# Using cached pyyaml-6.0.3-cp314-cp314-macosx_11_0_arm64.whl (173 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 562.2/562.2 kB 32.0 MB/s  0:00:00
# Using cached jsonpointer-3.1.1-py3-none-any.whl (7.7 kB)
# ...
