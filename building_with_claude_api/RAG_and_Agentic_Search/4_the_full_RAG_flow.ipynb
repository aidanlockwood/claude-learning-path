# %% [markdown]
# # The Full RAG Flow

# %% [markdown]
# ## Step 1: Chunk the Source Text

# %% [markdown]
# ## Step 2: Generate Embeddings
#
# Also applies normalisation to scale the vector pairs to a magnitude of between 0 and 1

# %% [markdown]
# ## Step 3: Store embeddings into vector database
#
# Done through the preprocessing step

# %% [markdown]
# ## Step 4: Embed User Query
#
# Feeding the User Query into the Vector Database to find the closest matched result.<br>
# Helps Claude to find the most relevant chunk to find the information to help the user

# %% [markdown]
# ## Step 5: Find the Closest Similarity Embeddings
# Uses Cosine Similarity

# %% [markdown]
# ### Cosine Distance
# - Values closest to 1 mean less similarity
# - Values closest to 0 mean more similarity

# %% [markdown]
# ## Step 6: Create the Final Prompt
